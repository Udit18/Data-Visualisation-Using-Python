# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/UditKhandelwal/Desktop/upGrad/Datasets/pokemon.csv')
df
df1=pd.read_csv('C:/Users/UditKhandelwal/Desktop/upGrad/Datasets/melbourne.csv')
df1
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
df1
# Out:
#                Suburb              Address  Rooms Type      Price Method  \
# 0          Abbotsford        68 Studley St      2    h        NaN     SS
# 1          Abbotsford         85 Turner St      2    h  1480000.0      S
# 2          Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 3          Abbotsford   18/659 Victoria St      3    u        NaN     VB
# 4          Abbotsford         5 Charles St      3    h  1465000.0     SP
# 5          Abbotsford     40 Federation La      3    h   850000.0     PI
# 6          Abbotsford          55a Park St      4    h  1600000.0     VB
# 7          Abbotsford         16 Maugie St      4    h        NaN     SN
# 8          Abbotsford         53 Turner St      2    h        NaN      S
# 9          Abbotsford         99 Turner St      2    h        NaN      S
# 10         Abbotsford       129 Charles St      2    h   941000.0      S
# 11         Abbotsford         124 Yarra St      3    h  1876000.0      S
# ...

# %%
plt.plot(df['HP'],df['Attack'])
plt.xlabel('HP')
plt.ylabel('Attack')
# Out:
# Text(0,0.5,'Attack')

# %%
plt.scatter(df['HP'],df['Attack'])

# %%
plt.scatter(df['HP'],df['Attack'],c="g",alpha=0.5)

# %%
plt.plot(df1['Car'],df1['Bathroom'],'bo')
plt.xlabel('Car')
plt.ylabel('Bathroom')
# Out:
# Text(0,0.5,'Bathroom')

# %%
plt.plot(df['HP'])

# %%
plt.hist([df['HP']])

# %%
t=np.arange(0.,5.,0.2)
t
plt.plot(t,t**2,'bo')
plt.xlabel('HP')
plt.ylabel('square')
# Out:
# Text(0,0.5,'square')

# %%
n=int(input())
t1=[]
for i in range(n):
    t1.append(int(input()))
plt.plot(np.array(t1),np.array(t1)**2,'r*')
# Out:
# 5
# 1
# 2
# 3
# 4
# 5

# %%
t2=np.arange(0.0,5.0,.2)
plt.plot(t2,np.cos(2*np.pi*t2),'r--')

# %%
sns.kdeplot(df['HP'],shade=True)
#plt.plot(df['HP'].mean())

# %%
sns.distplot(df['HP'],kde=False,norm_hist=True,color="r")
# Out:
# C:\Users\UditKhandelwal\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.plot([1,2,3],[4,8,-3])
plt.xlabel('Hp')
plt.ylabel('Num')
# Out:
# Text(0,0.5,'Num')

# %%
df1.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  03-09-2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  03-12-2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  04-02-2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  04-03-2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
sns.lmplot(y='Landsize',x='Bathroom',data=df1,hue='Type',fit_reg=False)

# %%
sns.countplot('Suburb',data=df1)

# %%
weather=pd.read_csv('C:/Users/UditKhandelwal/Desktop/upGrad/Datasets/weather.csv')

# %%
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am     ...       \
# 0           30.0         SW         NW           6.0     ...
# 1           39.0          E          W           4.0     ...
# 2           85.0          N        NNE           6.0     ...
# 3           54.0        WNW          W          30.0     ...
# 4           50.0        SSE        ESE          20.0     ...
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0           29       1019.7       1015.0         7         7     14.4
# ...

# %%
plt.figure(figsize=(20,8))
sns.boxplot(x='WindGustDir',y='WindSpeed3pm',data=weather,color="r")
sns.boxplot(x='WindGustDir',y='WindSpeed9am',data=weather,color="g")
