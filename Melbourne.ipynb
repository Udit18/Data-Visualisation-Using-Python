# %%
import os
import numpy as np
import pandas as pd

# %%
melbourne=pd.read_csv('C:/Users/UditKhandelwal/Desktop/upGrad/Datasets/melbourne.csv')

# %%
melbourne['Car'].value_counts(dropna=False).head()
# Out:
#  2.0    8088
#  1.0    7513
# NaN     4626
#  0.0    1385
#  3.0    1045
# Name: Car, dtype: int64

# %%
melbourne.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
melbourne.rows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c1013ddfca8a> in <module>()
# ----> 1 melbourne.rows()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
melbourne.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  23547.000000  1.839600e+04  23546.000000  23546.000000  19066.000000
# mean       2.976048  1.056697e+06     10.306515   3109.782893      2.951956
# std        0.974501  6.419217e+05      6.016318     94.522190      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.200000   3047.000000      2.000000
# 50%        3.000000  8.800000e+05      9.500000   3101.000000      3.000000
# 75%        4.000000  1.302000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  19063.000000  18921.000000   17410.000000  10018.000000  11540.000000
# mean       1.570897      1.626235     551.783458    154.527895   1964.636742
# ...

# %%
melbourne.count()
# Out:
# Suburb           23547
# Address          23547
# Rooms            23547
# Type             23547
# Price            18396
# Method           23547
# SellerG          23547
# Date             23547
# Distance         23546
# Postcode         23546
# Bedroom2         19066
# Bathroom         19063
# Car              18921
# Landsize         17410
# BuildingArea     10018
# YearBuilt        11540
# CouncilArea      15656
# Lattitude        19243
# Longtitude       19243
# Regionname       23546
# Propertycount    23546
# dtype: int64

# %%
melbourne['Price']=melbourne['Price'].fillna(melbourne['Price'].median())

# %%
melbourne['Car']
# Out:
# 0        1.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        0.0
# 5        1.0
# 6        2.0
# 7        2.0
# 8        2.0
# 9        1.0
# 10       0.0
# 11       0.0
# 12       1.0
# 13       0.0
# 14       2.0
# 15       NaN
# 16       NaN
# 17       1.0
# 18       2.0
# 19       NaN
# 20       1.0
# 21       NaN
# 22       NaN
# 23       1.0
# 24       2.0
# 25       1.0
# 26       NaN
# 27       NaN
# 28       1.0
# 29       1.0
#         ...
# 23517    2.0
# 23518    2.0
# 23519    3.0
# 23520    2.0
# 23521    2.0
# 23522    3.0
# 23523    2.0
# 23524    2.0
# 23525    2.0
# 23526    1.0
# 23527    1.0
# 23528    3.0
# 23529    2.0
# 23530    6.0
# 23531    NaN
# 23532    1.0
# 23533    2.0
# 23534    1.0
# 23535    2.0
# 23536    0.0
# 23537    2.0
# 23538    2.0
# 23539    4.0
# 23540    1.0
# 23541    5.0
# 23542    0.0
# 23543    NaN
# 23544    2.0
# 23545    1.0
# 23546    2.0
# Name: Car, Length: 23547, dtype: float64

# %%
mel_new=melbourne.isnull().sum()/melbourne.count()*100
round(mel_new,2)
# Out:
# Suburb             0.00
# Address            0.00
# Rooms              0.00
# Type               0.00
# Price              0.00
# Method             0.00
# SellerG            0.00
# Date               0.00
# Distance           0.00
# Postcode           0.00
# Bedroom2          23.50
# Bathroom          23.52
# Car               24.45
# Landsize          35.25
# BuildingArea     135.05
# YearBuilt        104.05
# CouncilArea       50.40
# Lattitude         22.37
# Longtitude        22.37
# Regionname         0.00
# Propertycount      0.00
# dtype: float64

# %%
# Out:
# Suburb             0.00
# Address            0.00
# Rooms              0.00
# Type               0.00
# Price              0.00
# Method             0.00
# SellerG            0.00
# Date               0.00
# Distance           0.00
# Postcode           0.00
# Bedroom2          23.50
# Bathroom          23.52
# Car               24.45
# Landsize          35.25
# BuildingArea     135.05
# YearBuilt        104.05
# CouncilArea       50.40
# Lattitude         22.37
# Longtitude        22.37
# Regionname         0.00
# Propertycount      0.00
# dtype: float64

# %%
melbourne.loc[::2]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 0             Abbotsford        68 Studley St      2    h   880000.0     SS
# 2             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 6             Abbotsford          55a Park St      4    h  1600000.0     VB
# 8             Abbotsford         53 Turner St      2    h   880000.0      S
# 10            Abbotsford       129 Charles St      2    h   941000.0      S
# 12            Abbotsford  121/56 Nicholson St      2    u   880000.0     PI
# 14            Abbotsford        98 Charles St      2    h  1636000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 18            Abbotsford        10 Valiant St      2    h  1097000.0      S
# 20            Abbotsford            2 Rich St      2    h   880000.0     SP
# ...

# %%
melbourne.iloc[4::4]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 4             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 8             Abbotsford         53 Turner St      2    h   880000.0      S
# 12            Abbotsford  121/56 Nicholson St      2    u   880000.0     PI
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 20            Abbotsford            2 Rich St      2    h   880000.0     SP
# 24            Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 28            Abbotsford        45 William St      2    h  1172500.0      S
# 32            Abbotsford          42 Henry St      3    h  1200000.0      S
# 36            Abbotsford     196 Nicholson St      3    h   955000.0      S
# 40            Abbotsford   13/11 Nicholson St      3    t   900000.0      S
# 44            Abbotsford           49 Park St      2    h  1315000.0      S
# ...

# %%
melbourne.iloc[melbourne>50,]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-a4bcbd2be7ea> in <module>()
# ----> 1 melbourne.iloc[melbourne>50,]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2027                 continue
#    2028
# -> 2029             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    2030
#    2031             # if the dim was reduced, then pass a lower-dim the next time
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2089         # a list of integers
# ...

# %%
melbourne[melbourne%4==0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1466         try:
# -> 1467             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1468         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/Hfu_PsEuD1Z_yJHmGaxWTxvkz7W_b0')
mel_new=df.isnull().sum()//df.sum()*100
print(round(mel_new,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
round(df.isnull().sum/df.count()*100,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
df.loc[8391,df.isnull().sum()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-47c8cc3da5a7> in <module>()
# ----> 1 df.loc[8391,df.isnull().sum()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1025                     return section
# ...

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
count=0
for i in range(df.shape[0]):
    if(df.loc[i,:].isna().sum()>5):
        df1.loc[i]=df.loc[i].fillna(0)
    else:
        df1.loc[i]=df.loc[i]
df1
# Out:
# Ord_id                 Ord_id                  Ord_5446
# Prod_id      ...
# Prod_id                Ord_id                  Ord_5406
# Prod_id      ...
# Ship_id                Ord_id                  Ord_5446
# Prod_id      ...
# Cust_id                Ord_id                  Ord_5456
# Prod_id      ...
# Sales                  Ord_id                  Ord_5485
# Prod_id      ...
# Discount               Ord_id                  Ord_5446
# Prod_id      ...
# Order_Quantity         Ord_id                  Ord_31
# Prod_id        ...
# Profit                 Ord_id                  Ord_4725
# Prod_id      ...
# Shipping_Cost          Ord_id                  Ord_4725
# Prod_id      ...
# Product_Base_Margin    Ord_id                  Ord_4725
# Prod_id      ...
# 0                      Ord_id                  Ord_5446
# Prod_id      ...
# 1                      Ord_id                  Ord_5406
# Prod_id      ...
# 2                      Ord_id                  Ord_5446
# ...

# %%
df['Product_Base_Margin']=df['Product_Base_Margin'].fillna(df['Product_Base_Margin'].mean())
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/Hfu_PsEuD1Z_yJHmGaxWTxvkz7W_b0')
df = df[df.isnull().sum(axis=1)<=5]
#print(missing_vnum)
#df.dropna(missing_vnum.item())
df.dropna()
columns = df.columns
percent_missing = df.isnull().sum() * 100 / len(df)
print(round(percent_missing,2))
# Out:
# Ord_id                 0.00
# Prod_id                0.00
# Ship_id                0.00
# Cust_id                0.00
# Sales                  0.00
# Discount               0.42
# Order_Quantity         0.42
# Profit                 0.42
# Shipping_Cost          0.42
# Product_Base_Margin    1.06
# dtype: float64
